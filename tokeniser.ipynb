# %% [markdown]
# ### Import Google Spreadsheet

# %%
import gspread
from google.oauth2.service_account import Credentials
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = Credentials.from_service_account_file('./sheet-274815-b5805997d72c.json', scopes=scope)
gc = gspread.authorize(credentials)
sh = gc.open_by_url('https://docs.google.com/spreadsheets/d/1uUxI7ZwIO25GccHz_k6UNMtfvO6SwTuskNBdptV5vyw/edit?usp=sharing')
worksheet_list = sh.worksheets()

print(worksheet_list)
# Out:
# [<Worksheet 'Bachelor + Master' id:2056597316>, <Worksheet 'Master' id:0>, <Worksheet 'Bachelor' id:1109562875>]

# %% [markdown]
# ### Select Degree

# %%
degree = 'Bachelor + Master'
sheet = sh.worksheet(degree)
print(sheet)
rows = sheet.get_all_values()
# Out:
# <Worksheet 'Bachelor + Master' id:2056597316>

# %% [markdown]
# ### Create Dictionary

# %%
import time
import string
import json
import glob
import spacy
from spacy import displacy

nlp = spacy.load("en_core_web_sm")

dictionary = {}

for i in range(1, len(rows)):
    row = rows[i]
    
    try:
        author = row[0] + ' ' + row[1]
        course = row[2]
        thesisTitle = row[3]
        text = row[4]
        doc = nlp(text)
        
        for sentence in doc.sents:
            for token in sentence:
                word = str(token).lower()
                content = {"title": thesisTitle, "course": course ,  "occurency" : 1}
                
                if word in dictionary: 
                    if author in dictionary[word]:
                        wordCount = int(dictionary[word][author]["occurency"])
                        content = {"title": thesisTitle, "course": course ,  "occurency" : wordCount + 1}
                        dictionary[word][author] =  content
                        
                        generalCount = int(dictionary[word]["occurency"])
                        dictionary[word]["occurency"] =  generalCount + 1
                        
                    else:
                        dictionary[word][author] =  content 
                        
                        generalCount = int(dictionary[word]["occurency"])
                        dictionary[word]["occurency"] =  generalCount + 1
                else:
                    dictionary[word] = { "occurency" : 1 , author : content}
        
    except Exception as e:
        print(e)
        break
    

output = open("./dictionary-" + degree.lower() + ".json", 'w')
json.dump(dictionary, output)
output.close()

print("Done!")
# Out:
# Done!

# %% [markdown]
# ### Sort by most occuring keys

# %%
clean = {}

for key in dictionary.keys():
    occurency = dictionary[key]["occurency"]
    clean[key] = occurency
# Out:
# {'the': 2353, 'movie': 3, 'is': 604, 'a': 1147, 'tale': 1, 'of': 1378, 'life': 49, 'and': 1277, 'spirit': 4, 'objects': 91, '.': 1727, 'in': 695, 'spite': 1, 'their': 156, 'very': 16, 'material': 58, 'physical': 32, 'quality': 11, ',': 1624, 'help': 12, 'us': 76, 'access': 10, 'an': 256, 'invisible': 4, 'world': 94, 'one': 82, 'way': 80, 'to': 1092, 'understand': 23, 'appreciate': 6, 'phenomena': 6, 'through': 102, 'reading': 4, 'study': 8, 'philosophy': 6, 'phenomenology': 1, 'more': 114, 'recently': 2, 'speculative': 4, 'realism': 1, 'granting': 1, 'agency': 2, 'just': 24, 'as': 330, 'importantly': 2, 'recognition': 4, 'object': 29, 'consciousness': 6, 'deeply': 4, 'rooted': 5, 'history': 27, 'making': 37, 'anthropology': 1, 'archeology': 1, 'particular': 4, 'demonstrate': 5, 'that': 364, 'has': 96, 'opened': 3, 'pandora': 1, "'s": 102, 'box': 2, 'cognition': 3, 'mould': 3, 'center': 4, 'point': 16, 'story': 14, 'allegory': 2, 'for': 288, 'design': 61, 'replacing': 2, 'simple': 8, 'methods': 8, 'mere': 1, 'additive': 1, 'reductive': 1, 'was': 36, 'developed': 7, 'during': 14, 'bronze': 1, 'age': 9, 'it': 319, 'great': 3, 'leap': 1, 'allowing': 10, 'give': 17, 'shape': 22, 'abstract': 5, 'thoughts': 6, 'beginning': 6, 'huge': 2, 'step': 5, 'second': 14, 'order': 25, 'instrumentality': 1, 'using': 28, 'make': 44, 'endless': 7, 'chain': 6, 'started': 14, ':': 55, 'etc': 6, 'became': 13, 'complex': 5, 'they': 99, 'have': 146, 'slowly': 6, 'escaped': 1, 'human': 50, 'control': 10, 'while': 30, 'helped': 1, 'reality': 25, 'created': 26, 'own': 40, 'at': 74, 'same': 29, 'time': 89, 'we': 214, 'made': 53, 'initially': 3, 'thought': 5, 'traditional': 15, 'project': 122, 'quickly': 3, 'animation': 3, 'addition': 2, 'being': 51, 'moving': 10, 'image': 27, 'technique': 10, 'ideal': 6, 'animist': 1, 'tool': 31, 'lending': 1, "'": 290, 'anima': 1, 'bringing': 6, 'things': 31, 'whole': 8, 'based': 47, 'on': 232, 'my': 106, 'personal': 17, 'experience': 45, ';': 29, 'nomad': 1, 'who': 37, 'frequently': 2, 'travels': 1, 'lives': 14, 'different': 59, 'countries': 12, 'cities': 5, 'i': 232, 'often': 26, 'think': 21, 'detached': 1, 'temporary': 7, 'relationship': 20, 'local': 31, 'place': 52, 'always': 20, 'plan': 2, 'next': 2, 'journey': 7, 'however': 16, 'this': 302, 'period': 10, 'self': 25, '-': 338, 'isolation': 2, 'gave': 3, 'me': 28, 'opportunity': 9, 'reflect': 15, 'how': 130, 'domestic': 7, 'space': 85, 'living': 24, 'environment': 39, 'will': 67, 'you': 98, 'still': 27, 'remember': 5, 'after': 21, 'leave': 6, '?': 100, 'what': 118, 'be': 197, 'left': 17, 'behind': 10, 'many': 31, 'memories': 9, 'from': 166, 'been': 58, 'work': 39, 'installation': 30, 'like': 57, 'snapshot': 1, 'capture': 4, 'last': 7, 'moment': 11, 'before': 14, 'current': 24, 'start': 15, 'new': 104, 'body': 59, '/': 25, 'performs': 1, 'critical': 7, 'paradoxical': 1, 'act': 13, 'non': 3, 'productive': 2, 'productivity': 6, 'durational': 2, 'pause': 3, 'comprising': 1, 'series': 23, 'devoted': 1, 'repetitions': 2, 'which': 106, 'serve': 11, 'interrupt': 1, 'narratives': 3, 'expectation': 1, 'efficiency': 3, 'embodied': 3, 'occupation': 4, 'form': 31, 'sabotage': 1, 'inspired': 16, 'by': 228, 'stories': 18, 'factory': 3, 'workers': 5, 'would': 38, 'gain': 5, 'momentary': 2, 'reprieve': 1, 'throwing': 1, 'parts': 15, 'into': 110, 'assembly': 4, 'line': 8, 'halt': 1, 'machines': 4, 'manifest': 3, 'textile': 16, 'works': 8, 'are': 266, 'exhausted': 3, 'process': 42, 'undoing': 2, 'redoing': 1, 'becoming': 11, 'garbled': 1, 'record': 2, 'past': 25, 'present': 18, 'hands': 4, 'bodies': 11, 'uncovers': 1, 'layers': 10, 'untold': 1, 'not': 102, 'quite': 3, 'free': 13, 'but': 114, 'only': 50, 'partially': 1, 'scripted': 1, 'partial': 1, 'script': 7, 'provides': 4, 'reconsidering': 2, 'rewriting': 1, 'retelling': 1, 'know': 11, 'about': 64, 'labour': 4, 'value': 28, 'presented': 6, 'combination': 1, 'performance': 15, 'artefacts': 4, 'asks': 2, 'actively': 3, 'stop': 9, 'occup ...

# %%
output = open("daeWords2021.tsv", 'w')

output.write("word\toccurence\tmetadata\n")

for (key, value) in sorted(clean.items(), key=lambda x: x[1], reverse=True):
    
    infos = []
    
    for chiave in dictionary[key]:
        if chiave == "occurency":
            continue
            
        title = dictionary[key][chiave]["title"]
        course = dictionary[key][chiave]["course"]
        occurency = dictionary[key][chiave]["occurency"]

        if "..." in title:
            continue
        
        infos.append(["student: "+ chiave,  "title: " + title, "course: " + course, "occurency: " + str(occurency)])

    #print("chiave", key)
    #print("value" , value)
    #print("thesis", json.dumps(infos))
    
    output.write(key + "\t" + str(value) + "\t" + str(infos) + "\n")

output.close()

# %%
import csv
from xlsxwriter.workbook import Workbook

# Add some command-line logic to read the file names.

tsv_file = 'daeWords2021.tsv'
xlsx_file = 'daeWords2021.xlsx'

# Create an XlsxWriter workbook object and add a worksheet.
workbook = Workbook(xlsx_file)
worksheet = workbook.add_worksheet()

# Create a TSV file reader.
tsv_reader = csv.reader(open(tsv_file, 'rt'), delimiter='\t')

# Read the row data from the TSV file and write it to the XLSX file.
for row, data in enumerate(tsv_reader):
    worksheet.write_row(row, 0, data)

# Close the XLSX file.
workbook.close()
